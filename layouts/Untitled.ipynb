# %%
import json
import itertools

obj = json.load(open("finalLED_s.json"))

# %%
def get_y(object):
    return object['point'][1]

def get_x(object):
    return object['point'][0]

# %%
g_obj = [list(g) for k, g in itertools.groupby(sorted(obj, key = get_y))]

# %%
srtd = sorted(obj, key = get_y)

# %%
srtd
# Out:
# [{u'point': [3.6864698292855325, -10.0, 0.047866640522801686]},
#  {u'point': [3.6285643583454315, -9.990799020341655, 0.2538672113212177]},
#  {u'point': [3.5685866914958493, -9.981268775898796, 0.4592590657766816]},
#  {u'point': [3.5065894884751456, -9.971417634122272, 0.6640352124669944]},
#  {u'point': [3.4424880121331465, -9.961232130571098, 0.868145834470903]},
#  {u'point': [3.376075352891875, -9.950679388026824, 1.071497250608436]},
#  {u'point': [3.3071689769655643, -9.939730402500333, 1.273996000650602]},
#  {u'point': [3.2355944966785635, -9.92835746439128, 1.4755433480835833]},
#  {u'point': [3.161171879532914, -9.916531967156544, 1.6760301635479053]},
#  {u'point': [3.0836693285173484, -9.904217079050357, 1.87531647091314]},
#  {u'point': [3.0028361508716013, -9.891372965857542, 2.0732411490190072]},
#  {u'point': [2.918418408014262, -9.877959277613172, 2.269624988270067]},
#  {u'point': [2.830110450964276, -9.863927447748122, 2.464246429368379]},
# ...
